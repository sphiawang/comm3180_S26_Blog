# %% [raw]
# ---
# title: "AI Literacy for College Students"
# description: "How can AI be responsibly used in a college setting?"
# author: "Sophia"
# date: "1/28/2026"
# image: LinkedInProfile.png
# categories:
#   - LLMs
#   - Academic
# ---

# %% [markdown]
# Here are my findings:

# %% [markdown]
# <img src="LinkedInProfile.png" width="400">
